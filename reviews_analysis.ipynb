# %% [markdown]
# # This notebook does some simple data analysis of a Goodread users reviews

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

reviews = pd.read_pickle('reviews_dataframe.pickle')
rated_books = reviews[reviews.my_rating.notna()]

# %%
rated_books = reviews[reviews.my_rating.notna()]
print(f"my average rating: {rated_books.my_rating.mean()}")
print(f"goodreads average rating of my read books: {rated_books.avg_rating.mean()}")

plt.title("Distribution of my ratings and average ratings")
sns.histplot(rated_books.my_rating, discrete=True, stat='density', label='my ratings')
sns.histplot(rated_books.avg_rating, bins=np.arange(0,5,1/4), stat='density', label='avg ratings')
plt.legend()
plt.show()
# Out:
# my average rating: 3.2083333333333335
# goodreads average rating of my read books: 3.9775
